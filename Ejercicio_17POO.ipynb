# %% [markdown]
# <a href="https://colab.research.google.com/github/evallejop/POO-Actividad-1/blob/main/Ejercicio_17POO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

class Calculos:

  @staticmethod
  def calcular_area_circulo(radio):
      return 2 * math.pi * radio

  @staticmethod
  def calcular_longitud_circunferencia(radio):
      return math.pi * math.pow(radio,2)

radio = 3
area_circulo = Calculos.calcular_area_circulo(radio)
longitud_circunferencia = Calculos.calcular_longitud_circunferencia(radio)

print("El área del círculo es = ", area_circulo)
print("La longitud de la circunferencia es = ", longitud_circunferencia)
# Out:
# El área del círculo es =  18.84955592153876
# La longitud de la circunferencia es =  28.274333882308138
